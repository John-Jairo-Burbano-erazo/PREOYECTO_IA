# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,r2_score

# %%
data=pd.read_excel('si-sustentabilidad-john.xlsx')

# %%
data.head()
# Out:
#        zafra  ... indice_de_sustentabilidad
# 0  2010-2011  ...                      3.06
# 1  2010-2011  ...                      2.90
# 2  2010-2011  ...                      2.56
# 3  2010-2011  ...                      3.36
# 4  2010-2011  ...                      1.12
#
# [5 rows x 24 columns]

# %%
data.describe()
# Out:
#        superficie_sembrada_con_labranza_de_conservacion  ...  indice_de_sustentabilidad
# count                                        114.000000  ...                 114.000000
# mean                                           0.023158  ...                   2.508947
# std                                            0.048742  ...                   0.506203
# min                                            0.000000  ...                   1.120000
# 25%                                            0.000000  ...                   2.150000
# 50%                                            0.000000  ...                   2.460000
# 75%                                            0.040000  ...                   2.875000
# max                                            0.200000  ...                   3.720000
#
# [8 rows x 19 columns]

# %%
data.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'superficie_sembrada_con_labranza_de_conservacion'}>,
#         <Axes: title={'center': 'superficie_sembrada_con_el_sistema_pina'}>,
#         <Axes: title={'center': 'superficie_sembrada_con_riego_tecnificado'}>,
#         <Axes: title={'center': 'superficie_fertilizada_con_base_en_recomendaciones_tecnicas'}>],
#        [<Axes: title={'center': 'superficie_con_aplicacion_de_abonos_organicos'}>,
#         <Axes: title={'center': 'superficie_con_aplicacion_de_biofertilizantes'}>,
#         <Axes: title={'center': 'superficie_atendida_con_manejo_integral_de_plagas'}>,
#         <Axes: title={'center': 'superficie_atendida_con_control_biologico'}>],
#        [<Axes: title={'center': 'superficie_atendida_con_el_programa_campo_limpio'}>,
#         <Axes: title={'center': 'superficie_cosechada_en_verde'}>,
#         <Axes: title={'center': 'rendimiento_promedio_de_cana_de_azucar'}>,
#         <Axes: title={'center': 'costo_de_produccion_por_tonelada'}>],
# ...

# %%
#asignamos nuestra variable dy.e entreda por entranamieneto y las etiquetas y.
datax=[["superficie_atendida_con_manejo_integral_de_plagas"]]
x_train= data[["superficie_atendida_con_manejo_integral_de_plagas"]]
y_train=data["superficie_atendida_con_control_biologico"].values

# %%
regr=linear_model.LinearRegression()

# entrenamos nuestro modelo
regr.fit(x_train, y_train)

# Hacemos las prediciones que en definitiva en una linea (en este caso,al ser 2D)
y_pred=regr.predict(x_train)

# veamos los coeficientes obtenidos, En nuestro caso, seran la Tangente
print('Coefficients: \n',regr.coef_)

# Este es el valor donde corta el eje Y (en X=0)
print('Intercept: \n',regr.intercept_)
# Error Cuadrado Modelo
print("Mean squared error: %.2f" % mean_squared_error(y_train,y_pred))
# Puntaje de Varianza. El mejor puntaje es 1.o
print('Variance score: %.2f' % r2_score(y_train,y_pred))
# Out:
# Coefficients:
#  [0.49500844]
# Intercept:
#  0.02576128986231003
# Mean squared error: 0.00
# Variance score: 0.59

# %%
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,r2_score

data=pd.read_excel('/content/si-sustentabilidad-john - copia.xlsx')

#asignamos nuestra variable dy.e entreda por entranamieneto y las etiquetas y.
datax=[["superficie_atendida_con_manejo_integral_de_plagas"]]
x_train= data[["superficie_atendida_con_manejo_integral_de_plagas"]]
y_train=data["superficie_atendida_con_control_biologico"].values

# Create a linear regression model
model = linear_model.LinearRegression()

# Fit the model to the training data
model.fit(x_train, y_train)

# Make predictions
y_pred = model.predict(x_train)

# Print the coefficients, intercept, mean squared error, and variance score
print('Coefficients: \n', model.coef_)
print('Intercept: \n', model.intercept_)
print("Mean squared error: %.2f" % mean_squared_error(y_train, y_pred))
print('Variance score: %.2f' % r2_score(y_train, y_pred))
# Out:
# Coefficients:
#  [0.49500844]
# Intercept:
#  0.02576128986231003
# Mean squared error: 0.00
# Variance score: 0.59

# %%
import matplotlib.pyplot as plt

# Plot the data points
plt.scatter(x_train, y_train, color='blue', label='Actual Data')

# Plot the regression line
plt.plot(x_train, y_pred, color='red', linewidth=2, label='Regression Line')

# Add labels and title
plt.xlabel('Superficie atendida con manejo integral de plagas')
plt.ylabel('Superficie atendida con control biologico')
plt.title('Linear Regression Analysis')
plt.legend()
plt.show()

# %%
# Sort the data by 'indice_de_sustentabilidad' in descending order
sorted_data = data.sort_values(by='indice_de_sustentabilidad', ascending=False)

# Display the relevant columns (e.g., 'ingenio' or 'sector' and 'indice_de_sustentabilidad')
display(sorted_data[['ingenio', 'sector', 'indice_de_sustentabilidad']])
# Out:
#                     ingenio   sector  indice_de_sustentabilidad
# 33                 queseria  privado                       3.72
# 37   san_miguel_del_naranjo  privado                       3.54
# 99                la_gloria  privado                       3.50
# 43                 tamazula  privado                       3.48
# 102              mahuixtlan  privado                       3.44
# ..                      ...      ...                        ...
# 54                la_gloria  privado                       1.62
# 22                  la_joya  privado                       1.60
# 27      nuevo_san_francisco  privado                       1.58
# 62          alianza_popular  privado                       1.40
# 4                 azsuremex  privado                       1.12
#
# [114 rows x 3 columns]
